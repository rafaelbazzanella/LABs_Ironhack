# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
#!pip install stackapi

# %%
# your code here
import requests
from stackapi import StackAPI
from datetime import datetime
import pandas as pd

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
# your code here
site = StackAPI('stackoverflow')
date_start = int(datetime.timestamp(datetime(2020,3,1)))
date_end = int(datetime.timestamp(datetime(2020,3,31)))
questions = site.fetch('questions', fromdate=date_start, todate=date_end)
answers = site.fetch('answers', fromdate=date_start, todate=date_end)

questions = pd.json_normalize(questions['items'])
answers = pd.json_normalize(answers['items'])

# %%
questions
# Out:
#                                                   tags  is_answered  \
# 0                                             [python]        False
# 1                           [reactjs, typescript, svg]        False
# 2                                 [verilog, flip-flop]         True
# 3                                   [verilog, quartus]         True
# 4           [oracle, loops, if-statement, join, plsql]         True
# ..                                                 ...          ...
# 495                                 [node.js, reactjs]         True
# 496    [c#, sql, sql-server, windows, sql-server-2014]         True
# 497                                            [swift]        False
# 498                  [php, laravel, jobs, laravel-5.8]         True
# 499  [javascript, jquery, jquery-ui-sortable, jquer...         True
#
#      view_count  answer_count  score  last_activity_date  creation_date  \
# 0            11             0      0          1587154653     1584700767
# ...

# %%
answers
# Out:
#      is_accepted  score  last_activity_date  last_edit_date  creation_date  \
# 0          False      0          1587154086      1587154086     1584843533
# 1          False      0          1587151945      1587151945     1584081607
# 2          False      0          1587150508      1587150508     1585182113
# 3          False      1          1587143352      1587143352     1583356335
# 4           True      3          1587138133      1587138133     1584371763
# ..           ...    ...                 ...             ...            ...
# 495        False      1          1586247358      1586247358     1585581596
# 496         True      2          1586246792      1586246792     1585238385
# 497         True      4          1586245201      1586245201     1585590338
# 498        False      1          1586244293      1586244293     1583856434
# 499         True      0          1586243436      1586243436     1585415406
#
# ...

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here
yesterday = int(datetime.timestamp(datetime(2020,3,30, 23, 59, 59)))
tomorrow = int(datetime.timestamp(datetime(2020,3,31, 23, 59, 59)))
question = site.fetch('questions', fromdate=yesterday, todate=tomorrow, tagged='python', sort='votes', min=5, order='desc' )
pd.json_normalize(question['items'][0])
# Out:
#                tags  is_answered  view_count  accepted_answer_id  \
# 0  [python, django]         True         113            61027987
#
#    answer_count  score  last_activity_date  creation_date  last_edit_date  \
# 0             2      7          1586581021     1585693530      1586061149
#
#    question_id                                               link  \
# 0     60960889  https://stackoverflow.com/questions/60960889/d...
#
#                                                title  owner.reputation  \
# 0  Django formset creates multiple inputs for mul...              5816
#
#    owner.user_id owner.user_type  \
# 0       10698741      registered
#
#                                  owner.profile_image owner.display_name  \
# 0  https://www.gravatar.com/avatar/20e83447969ece...             dgknca
#
#                                         owner.link
# 0  https://stackoverflow.com/users/10698741/dgknca

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here
answers = site.fetch('answers', ids=[6784,6473])
answers
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'owner': {'reputation': 28695,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=128&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
#     'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1218291583,
#    'creation_date': 1218291583,
#    'answer_id': 6784,
#    'question_id': 6778}]}
