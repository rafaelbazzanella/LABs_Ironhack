# %% [markdown]
# # Interactive Visualization Lab
#
# Complete the following set of exercises to solidify your knowledge of interactive visualization using Plotly, Cufflinks, and IPyWidgets.

# %%
import pandas as pd
import plotly.plotly as py
import cufflinks as cf
from ipywidgets import interact
import matplotlib.pyplot as plt

cf.go_offline()

import pandas as pd;
import plotly.offline as py;
from plotly import tools;
import plotly.graph_objs as go;
import warnings;
from ipywidgets import interact;

warnings.filterwarnings('ignore')
py.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
data = pd.read_excel('../data/Online Retail.xlsx')

# %%
data.head()
# Out:
#    InvoiceNo         InvoiceDate StockCode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           Description  Quantity  UnitPrice  Revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    CustomerID         Country
# 0       17850  United Kingdom
# 1       17850  United Kingdom
# 2       17850  United Kingdom
# 3       17511  United Kingdom
# 4       13408  United Kingdom

# %% [markdown]
# ## 1. Create an interactive bar chart showing total quantity and revenue by country (excluding United Kingdom) for the month of April 2011.

# %%
print(data['Country'].unique())
# Out:
# ['United Kingdom' 'Spain' 'Cyprus' 'EIRE' 'Portugal' 'Netherlands'
#  'Australia' 'Singapore' 'Switzerland' 'Finland' 'Channel Islands'
#  'France' 'Malta' 'Italy' 'Israel' 'Germany' 'Austria' 'Norway' 'Denmark'
#  'Sweden' 'Belgium' 'Canada' 'Poland' 'Japan' 'Iceland' 'Greece' 'Lebanon'
#  'South Africa' 'Czech Republic' 'USA' 'Brazil' 'United Arab Emirates'
#  'Lithuania' 'Saudi Arabia' 'Bahrain']

# %%
type(data['InvoiceDate'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
data['total_quantity']=data['Quantity']*data['UnitPrice']

# %%
data[(data['InvoiceDate'].dt.month==4) & (data['InvoiceDate'].dt.year==2011)]
# Out:
#         InvoiceNo         InvoiceDate StockCode  \
# 665        548550 2011-04-01 08:22:00    85123A
# 666        548552 2011-04-01 09:06:00    85123A
# 667        548560 2011-04-01 10:10:00    85123A
# 668        548561 2011-04-01 10:11:00    85123A
# 669        548610 2011-04-01 11:28:00    85123A
# ...           ...                 ...       ...
# 333694     551414 2011-04-28 13:35:00     23041
# 333742     551414 2011-04-28 13:35:00     23040
# 333780     551414 2011-04-28 13:35:00     23064
# 333781     551462 2011-04-28 16:11:00     23064
# 333802     551462 2011-04-28 16:11:00     85225
#
#                                Description  Quantity  UnitPrice  Revenue  \
# 665     CREAM HANGING HEART T-LIGHT HOLDER         6       2.95    17.70
# 666     CREAM HANGING HEART T-LIGHT HOLDER        12       2.95    35.40
# 667     CREAM HANGING HEART T-LIGHT HOLDER        32       2.55    81.60
# 668     CREAM HANGING HEART T-LIGHT HOLDER         6       2.95    17.70
# ...

# %%
data[(data['Country']!='United Kingdom')&(data['InvoiceDate'].dt.month==4) & (data['InvoiceDate'].dt.year==2011)][['Country','total_quantity','Revenue','InvoiceDate']]

#como posso fazer a soma sem mexer com os outros? somar coluna de quantidade
# Out:
#             Country  total_quantity  Revenue         InvoiceDate
# 724            EIRE           17.70    17.70 2011-04-11 12:20:00
# 807          France           26.55    26.55 2011-04-26 15:52:00
# 3320    Switzerland           17.00    17.00 2011-04-21 12:07:00
# 4880        Germany           67.60    67.60 2011-04-19 10:48:00
# 4882        Germany           54.08    54.08 2011-04-19 13:39:00
# ...             ...             ...      ...                 ...
# 328231      Germany           42.50    42.50 2011-04-20 09:31:00
# 328238        Spain            8.50     8.50 2011-04-21 13:11:00
# 328244      Germany           17.00    17.00 2011-04-27 12:02:00
# 328681      Belgium           16.50    16.50 2011-04-28 09:12:00
# 329262      Germany           25.00    25.00 2011-04-14 13:59:00
#
# [1688 rows x 4 columns]

# %%
data[(data['Country']!='United Kingdom')&(data['InvoiceDate'].dt.month==4) & (data['InvoiceDate'].dt.year==2011)][['Country','total_quantity','Revenue']].iplot(kind='bar', x='Country' )
# Out:
# <div>
#
#
#             <div id="0e36cd36-68e4-4b99-9798-b8b2acf67fca" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0e36cd36-68e4-4b99-9798-b8b2acf67fca")) {
#                     Plotly.newPlot(
#                         '0e36cd36-68e4-4b99-9798-b8b2acf67fca',
# ...

# %% [markdown]
# ## 2. Create an interactive line chart showing quantity and revenue sold to France between January 1st and May 31st 2011.

# %%
data[(data['Country']=='France')&(data['InvoiceDate'].dt.month>=1) &(data['InvoiceDate'].dt.month<=5) & (data['InvoiceDate'].dt.year==2011)][['Quantity','Revenue','InvoiceDate']].sort_values(by=['InvoiceDate']).iplot(kind='line', x='InvoiceDate' )
# Out:
# <div>
#
#
#             <div id="cc7d10e4-a751-4886-9cf0-87f97a3e23dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("cc7d10e4-a751-4886-9cf0-87f97a3e23dc")) {
#                     Plotly.newPlot(
#                         'cc7d10e4-a751-4886-9cf0-87f97a3e23dc',
# ...

# %%
data.head()
# Out:
#    InvoiceNo         InvoiceDate StockCode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           Description  Quantity  UnitPrice  Revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    CustomerID         Country  total_quantity
# 0       17850  United Kingdom            15.3
# 1       17850  United Kingdom            15.3
# 2       17850  United Kingdom            15.3
# 3       17511  United Kingdom           163.2
# 4       13408  United Kingdom            81.6

# %%
#data.plot(kind='line', x='tenure')

# %% [markdown]
# ## 3. Create an interactive scatter plot showing the relationship between average quantity (x-axis) and average unit price (y-axis) for the product PARTY BUNTING with the plot points color-coded by country (categories).

# %%
data[data['Description']=='PARTY BUNTING'].head(3)
# Out:
#         InvoiceNo         InvoiceDate StockCode    Description  Quantity  \
# 252864     536956 2010-12-03 12:43:00     47566  PARTY BUNTING         5
# 252865     537065 2010-12-05 11:57:00     47566  PARTY BUNTING         5
# 252866     537128 2010-12-05 12:15:00     47566  PARTY BUNTING         2
#
#         UnitPrice  Revenue  CustomerID         Country  total_quantity
# 252864       4.65    23.25       14210  United Kingdom           23.25
# 252865       4.65    23.25       12567          France           23.25
# 252866       4.65     9.30       12841  United Kingdom            9.30

# %%
data[data['Description']=='PARTY BUNTING'].iplot(kind='scatter',x='Quantity',y='UnitPrice',categories='Country')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\cufflinks\plotlytools.py:805: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# C:\Users\User\Anaconda3\lib\site-packages\cufflinks\plotlytools.py:808: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>
#
#
#             <div id="8a1074ad-6852-4af5-b054-7f3e178daa10" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8a1074ad-6852-4af5-b054-7f3e178daa10")) {
#                     Plotly.newPlot(
#                         '8a1074ad-6852-4af5-b054-7f3e178daa10',
# ...

# %% [markdown]
# ## 4. Create a set of interactive histograms showing the distributions of quantity per invoice for the following countries: EIRE, Germany, France, and Netherlands.

# %%
data_4 = data[(data['Country']=='EIRE')|(data['Country']=='Germany')|(data['Country']=='France')|(data['Country']=='Netherlands')]
data_4.head()
#data[data['Country'] == ('EIRE'|'Germany'|'France'|'Netherlands')]
# Out:
#      InvoiceNo         InvoiceDate StockCode  \
# 179     539320 2010-12-16 19:16:00    85123A
# 198     539722 2010-12-21 13:45:00    85123A
# 304     541570 2011-01-19 12:34:00    85123A
# 322     541979 2011-01-24 14:54:00    85123A
# 367     542777 2011-02-01 08:31:00    85123A
#
#                             Description  Quantity  UnitPrice  Revenue  \
# 179  CREAM HANGING HEART T-LIGHT HOLDER        24       2.95     70.8
# 198  CREAM HANGING HEART T-LIGHT HOLDER        24       2.95     70.8
# 304  CREAM HANGING HEART T-LIGHT HOLDER       256       2.55    652.8
# 322  CREAM HANGING HEART T-LIGHT HOLDER         6       2.95     17.7
# 367  CREAM HANGING HEART T-LIGHT HOLDER         6       2.95     17.7
#
#      CustomerID      Country  total_quantity
# 179       14911         EIRE            70.8
# 198       14911         EIRE            70.8
# 304       14646  Netherlands           652.8
# 322       14911         EIRE            17.7
# ...

# %%
data_4[['Quantity','InvoiceNo']].describe().T
# Out:
#              count           mean           std       min       25%       50%  \
# Quantity   26150.0      21.767075     47.214894       1.0       6.0      12.0
# InvoiceNo  26150.0  560556.624818  12590.410167  536370.0  549667.0  562035.0
#
#                 75%       max
# Quantity       20.0    2400.0
# InvoiceNo  570792.0  581587.0

# %%
import plotly.graph_objs as go    
layout = go.Layout(xaxis=dict(range=[500000, 600000]),yaxis=dict(range=[0, 1000]))

# %%
data_4[['Quantity','InvoiceNo']].iplot(kind='hist', layout =layout )
# Out:
# <div>
#
#
#             <div id="69b90877-2de5-4521-98d3-c7214130cb12" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("69b90877-2de5-4521-98d3-c7214130cb12")) {
#                     Plotly.newPlot(
#                         '69b90877-2de5-4521-98d3-c7214130cb12',
# ...

# %% [markdown]
# ## 5. Create an interactive side-by-side bar chart showing the revenue by country listed below (bars) for each of the products listed below.

# %%
product_list = ['JUMBO BAG RED RETROSPOT','CREAM HANGING HEART T-LIGHT HOLDER','REGENCY CAKESTAND 3 TIER']
country_list = ['EIRE', 'Germany', 'France', 'Netherlands']

# %%
data.head(2)
# Out:
#    InvoiceNo         InvoiceDate StockCode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
#
#                           Description  Quantity  UnitPrice  Revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
#
#    CustomerID         Country  total_quantity  Year  Month  Day
# 0       17850  United Kingdom            15.3  2010     12    1
# 1       17850  United Kingdom            15.3  2010     12    1

# %%
df = data[data['Country'].isin(country_list) & data['Description'].isin(product_list)]
df = df.pivot_table(index='Country', columns='Description', values='Revenue', aggfunc='sum');

# %%
# Traces
traces = [go.Bar(x=df.index, y=df[column], name=column) for column in df.columns];

# Layout
layout = go.Layout(barmode='group', width=1000, height=500,
                   xaxis=go.layout.XAxis(title=go.layout.xaxis.Title(text='Country')),
                   yaxis=go.layout.YAxis(title=go.layout.yaxis.Title(text='Total Revenue')),
                   title=go.layout.Title(text='Total Revenue per Country for given products'));

# Plot
py.iplot(go.Figure(data=traces, layout=layout));
# Out:
# <div>
#
#
#             <div id="c5ed0526-425a-4411-996d-ae7ee9191014" class="plotly-graph-div" style="height:500px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c5ed0526-425a-4411-996d-ae7ee9191014")) {
#                     Plotly.newPlot(
#                         'c5ed0526-425a-4411-996d-ae7ee9191014',
# ...

# %% [markdown]
# ## 6. Create an interactive line chart showing quantity sold by day for the United Kingdom. Add drop-down boxes for Year and Month that allow you to filter the date range that appears in the chart.

# %%
data['Year'] = pd.DatetimeIndex(data['InvoiceDate']).year
data['Month'] = pd.DatetimeIndex(data['InvoiceDate']).month
data['Day'] = pd.DatetimeIndex(data['InvoiceDate']).day
uk = data[data['Country']=='United Kingdom']

# %%
years = uk['Year'].unique();
months = uk['Month'].unique();
months.sort();

# %%
# Interactive menu
@interact(year=years, 
          month=months)

# Update function
def linechart(year=2011, month=4):
    # Transform the data
    sales_date = uk[(uk['Year']==year) & (uk['Month']==month)];
    sales_day = sales_date.groupby('Day').sum()['Quantity'];
    # Traces
    traces = [go.Scatter(x=sales_day.index, y=sales_day)];
    # Layout
    layout = go.Layout(width=1000, height=500,
                       xaxis=go.layout.XAxis(title=go.layout.xaxis.Title(text='Day')),
                       yaxis=go.layout.YAxis(title=go.layout.yaxis.Title(text='Quantity')),
                       title=go.layout.Title(text=f'Total Quantity sold in UK ({month}-{year})'));
    # Plot
    py.iplot(go.Figure(data=traces, layout=layout));
# Out:
# interactive(children=(Dropdown(description='year', index=1, options=(2010, 2011), value=2011), Dropdown(descri…

# %% [markdown]
# ## 7. Create an interactive scatter plot that plots number of invoices (x-axis) vs. number of customers (y-axis) and the plot points represent individual products. Add two sliders that control the x and y axis ranges.

# %%
agg_func = {'InvoiceNo':'nunique',
            'Quantity':'sum',
            'UnitPrice':'mean',
            'Revenue':'sum',
            'CustomerID':'nunique'}

products = uk.groupby('Description').agg(agg_func)

# %%
# Interactive menu
@interact(invoices=(products['InvoiceNo'].min(), products['InvoiceNo'].max(), 10), 
          customers=(products['CustomerID'].min(), products['CustomerID'].max(), 10))

# Update function
def scatter(invoices=1, customers=1):
    # Transform the data
    filtered = products[(products['CustomerID'] > customers) & 
                  (products['InvoiceNo'] > invoices)]
    # Traces
    traces = [go.Scatter(x=filtered['InvoiceNo'], 
                         y=filtered['CustomerID'], 
                         mode='markers')]
    # Layout 
    layout = go.Layout(width=700, height=600,
                       xaxis=go.layout.XAxis(title=go.layout.xaxis.Title(text='#Invoices')),
                       yaxis=go.layout.YAxis(title=go.layout.yaxis.Title(text='#Customers')),
                       title=go.layout.Title(text='Number of Invoices VS Number of Customers'));
    # Plot
    py.iplot(go.Figure(data=traces, layout=layout));
# Out:
# interactive(children=(IntSlider(value=1, description='invoices', max=1891, min=1, step=10), IntSlider(value=1,…

# %% [markdown]
# ## 8. Creat an interactive bar chart that shows revenue by product description. Add a text field widget that filters the results to show the product that contain the text entered in their description.

# %%
# Interactive menu
@interact(product='')

# Update function
def chart(product):
    # Transform the data
    filtered = data[data['Description'].str.contains(product.upper())]
    prdct_rvn = filtered.groupby('Description')['Revenue'].sum()
    # Traces
    traces = [go.Bar(x=prdct_rvn.index, y=prdct_rvn)];
    # Layout
    layout = go.Layout(width=1000, height=500,
                   yaxis=go.layout.YAxis(title=go.layout.yaxis.Title(text='Total Revenue')),
                   title=go.layout.Title(text='Total Revenue per Product'));
    # Plot
    py.iplot(go.Figure(data=traces, layout=layout));
# Out:
# interactive(children=(Text(value='', description='product'), Output()), _dom_classes=('widget-interact',))
